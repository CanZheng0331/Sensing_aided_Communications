# %% [markdown]
# <a href="https://colab.research.google.com/github/CanZheng0331/Sensing_aided_Communications/blob/main/Computer_Vision_Aided_Beam_Tracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# This is a Python code package related to the following article: S. Jiang and A. Alkhateeb, "**Computer Vision Aided Beam Tracking** in A Real-World Millimeter Wave Deployment," in IEEE Globecom Workshops, 2022.
#
# The original open sourced code is in: https://github.com/acyiobs/vision_beam_tracking/tree/main.
#
# Most of the annotations are written in Chinese.

# %%
## 下载 场景8 数据集、视觉数据标注（YOLO V4 识别的 2D 边界框的坐标和属性）并解压

# !wget -q -O scenario8.zip "https://www.dropbox.com/scl/fi/6yhd4xddx7d2zk4mcllq6/scenario8.zip?rlkey=w472s91e9tvv5p78yszkxmww3&e=1&dl=0"
# !wget -q -O camera_data_bbox.zip "https://www.dropbox.com/scl/fi/n1cqbxvpzxl9j4zhhgs3q/camera_data_bbox.zip?dl=0&e=1&rlkey=cibk7natbsm2axb8gzrvz12rl"
# !unzip scenario8.zip
# !unzip camera_data_bbox.zip -d "/content/DEV[95%]/unit1"
# Out:
# 流式输出内容被截断，只能显示最后 5000 行内容。
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4099.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_41.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_410.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4100.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4101.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4102.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4103.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4104.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4105.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4106.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4107.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4108.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4109.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_411.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4110.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4111.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4112.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4113.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4114.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4115.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4116.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4117.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4118.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4119.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_412.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4120.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4121.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4122.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4123.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4124.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4125.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4126.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4127.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4128.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4129.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_413.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4130.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4131.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4132.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4133.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4134.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4135.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4136.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4137.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4138.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4139.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_414.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4140.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4141.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4142.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4143.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4144.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4145.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4146.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4147.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4148.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4149.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_415.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4150.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4151.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4152.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4153.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4154.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4155.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4156.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4157.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4158.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4159.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_416.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4160.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4161.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4162.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4163.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4164.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4165.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4166.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4167.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4168.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4169.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_417.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4170.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4171.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4172.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4173.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4174.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4175.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4176.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4177.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4178.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4179.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_418.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4180.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4181.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4182.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4183.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4184.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4185.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4186.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4187.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4188.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4189.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_419.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4190.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4191.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4192.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4193.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4194.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4195.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4196.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4197.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4198.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4199.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_42.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_420.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4200.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4201.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4202.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4203.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4204.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4205.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4206.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4207.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4208.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4209.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_421.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4210.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4211.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4212.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4213.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4214.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4215.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4216.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4217.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4218.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4219.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_422.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4220.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4221.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4222.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4223.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4224.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4225.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4226.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4227.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4228.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4229.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_423.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4230.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4231.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4232.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4233.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4234.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4235.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4236.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4237.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4238.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4239.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_424.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4240.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4241.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4242.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4243.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4244.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4245.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4246.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4247.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4248.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4249.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_425.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4250.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4251.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4252.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4253.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4254.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4255.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4256.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4257.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4258.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4259.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_426.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4260.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4261.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4262.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4263.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4264.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4265.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4266.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4267.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4268.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4269.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_427.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4270.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4271.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4272.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4273.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4274.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4275.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4276.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4277.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4278.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4279.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_428.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4280.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4281.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4282.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4283.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4284.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4285.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4286.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4287.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4288.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4289.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_429.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4290.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4291.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4292.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4293.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4294.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4295.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4296.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4297.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4298.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4299.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_43.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_430.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4300.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4301.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_4302.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_431.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_432.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_433.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_434.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_435.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_436.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_437.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_438.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_439.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_44.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_440.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_441.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_442.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_443.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_444.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_445.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_446.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_447.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_45.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_46.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_47.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_48.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_49.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_5.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_50.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_505.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_506.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_507.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_508.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_509.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_51.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_510.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_511.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_512.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_513.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_514.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_515.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_516.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_517.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_518.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_519.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_52.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_520.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_521.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_522.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_523.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_524.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_525.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_526.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_527.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_528.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_529.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_53.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_530.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_531.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_532.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_533.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_534.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_535.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_536.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_537.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_538.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_539.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_54.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_540.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_541.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_542.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_543.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_544.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_545.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_546.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_547.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_548.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_549.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_55.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_550.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_551.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_552.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_553.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_554.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_555.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_556.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_557.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_558.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_559.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_56.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_560.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_561.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_562.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_563.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_564.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_565.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_566.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_567.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_568.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_569.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_57.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_570.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_571.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_572.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_573.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_574.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_575.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_576.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_577.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_578.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_579.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_58.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_580.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_581.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_582.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_583.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_584.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_585.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_586.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_587.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_588.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_589.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_59.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_590.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_591.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_592.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_593.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_594.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_595.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_596.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_597.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_598.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_599.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_6.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_60.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_600.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_601.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_602.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_603.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_604.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_605.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_606.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_607.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_608.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_609.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_61.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_610.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_611.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_612.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_613.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_614.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_615.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_616.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_617.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_618.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_619.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_62.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_620.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_621.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_622.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_623.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_624.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_625.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_626.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_627.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_628.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_629.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_63.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_630.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_631.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_632.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_633.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_634.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_635.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_636.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_637.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_638.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_639.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_64.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_640.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_641.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_642.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_643.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_644.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_645.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_646.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_647.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_648.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_649.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_65.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_650.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_651.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_652.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_653.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_654.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_655.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_656.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_657.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_658.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_659.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_66.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_660.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_661.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_662.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_663.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_664.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_665.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_666.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_667.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_668.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_669.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_67.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_670.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_671.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_672.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_673.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_674.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_675.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_676.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_677.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_678.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_679.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_68.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_680.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_681.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_682.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_683.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_684.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_685.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_686.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_687.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_688.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_689.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_69.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_690.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_691.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_692.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_693.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_694.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_695.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_696.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_697.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_698.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_699.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_7.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_70.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_700.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_701.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_702.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_703.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_704.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_705.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_706.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_707.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_708.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_709.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_71.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_710.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_711.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_712.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_713.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_714.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_715.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_716.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_717.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_718.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_719.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_72.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_720.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_721.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_722.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_723.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_724.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_725.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_726.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_727.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_728.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_729.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_73.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_730.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_731.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_732.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_733.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_734.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_735.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_736.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_737.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_738.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_739.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_74.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_740.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_741.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_742.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_743.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_744.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_745.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_746.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_747.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_748.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_749.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_75.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_750.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_751.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_752.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_753.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_754.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_755.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_756.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_757.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_758.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_759.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_76.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_760.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_761.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_762.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_763.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_764.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_765.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_766.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_767.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_768.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_769.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_77.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_770.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_771.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_772.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_773.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_774.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_775.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_776.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_777.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_778.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_779.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_78.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_780.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_781.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_782.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_783.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_784.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_785.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_786.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_787.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_788.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_789.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_79.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_790.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_791.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_792.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_793.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_794.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_795.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_796.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_797.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_798.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_799.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_8.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_80.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_800.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_801.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_802.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_803.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_804.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_805.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_806.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_807.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_808.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_809.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_81.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_810.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_811.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_812.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_813.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_82.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_83.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_84.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_85.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_86.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_866.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_867.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_868.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_869.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_87.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_870.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_871.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_872.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_873.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_874.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_875.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_876.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_877.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_878.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_879.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_88.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_880.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_881.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_882.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_883.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_884.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_885.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_886.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_887.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_888.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_889.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_89.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_890.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_891.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_892.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_893.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_894.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_895.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_896.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_897.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_898.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_899.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_9.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_90.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_900.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_901.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_902.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_903.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_904.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_905.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_906.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_907.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_908.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_909.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_91.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_910.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_911.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_912.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_913.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_914.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_915.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_916.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_917.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_918.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_919.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_92.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_93.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_94.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_95.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_96.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_97.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_975.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_976.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_977.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_978.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_979.txt
#   inflating: DEV[95%]/unit2/GPS_data_calibrated/gps_location_98.txt
# ...
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9032_22_27_37.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9033_22_27_37.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9034_22_27_38.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9035_22_27_38.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9036_22_27_38.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9037_22_27_38.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9038_22_27_38.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9039_22_27_38.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9040_22_27_38.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9041_22_27_38.txt
#   inflating: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9042_22_27_38.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9043_22_27_39.txt
#   inflating: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9323_22_28_10.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9324_22_28_10.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9325_22_28_10.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9326_22_28_10.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9327_22_28_10.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9328_22_28_10.txt
#   inflating: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9329_22_28_10.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9330_22_28_10.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9331_22_28_11.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9332_22_28_11.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9333_22_28_11.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9334_22_28_11.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9335_22_28_11.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9336_22_28_11.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9337_22_28_11.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9338_22_28_11.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9339_22_28_11.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9340_22_28_12.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9341_22_28_12.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9342_22_28_12.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9343_22_28_12.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9344_22_28_12.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9345_22_28_12.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9346_22_28_12.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9347_22_28_12.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9348_22_28_12.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9349_22_28_13.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9350_22_28_13.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9351_22_28_13.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9352_22_28_13.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9353_22_28_13.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9354_22_28_13.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9355_22_28_13.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9356_22_28_13.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9357_22_28_13.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9358_22_28_14.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9359_22_28_14.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9360_22_28_14.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9361_22_28_14.txt
#   inflating: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9362_22_28_14.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9363_22_28_14.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9364_22_28_14.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9365_22_28_14.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9366_22_28_14.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9367_22_28_15.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9368_22_28_15.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9369_22_28_15.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9370_22_28_15.txt
#   inflating: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9371_22_28_15.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9372_22_28_15.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9373_22_28_15.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9374_22_28_15.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_957_22_12_39.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_958_22_12_40.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_959_22_12_40.txt
#   inflating: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_960_22_12_40.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_961_22_12_40.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_962_22_12_40.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_963_22_12_40.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_964_22_12_40.txt
#   inflating: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_965_22_12_40.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9665_22_28_48.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9666_22_28_48.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9667_22_28_48.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9668_22_28_48.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9669_22_28_48.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_966_22_12_41.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9670_22_28_48.txt
#   inflating: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9671_22_28_48.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9672_22_28_48.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9673_22_28_49.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9674_22_28_49.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9675_22_28_49.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9676_22_28_49.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9677_22_28_49.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9678_22_28_49.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9679_22_28_49.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_967_22_12_41.txt
#   inflating: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9680_22_28_49.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9681_22_28_49.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9682_22_28_50.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9683_22_28_50.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9684_22_28_50.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9685_22_28_50.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9686_22_28_50.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9687_22_28_50.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9688_22_28_50.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9689_22_28_50.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_968_22_12_41.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9690_22_28_50.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9691_22_28_51.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9692_22_28_51.txt
#   inflating: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9693_22_28_51.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9694_22_28_51.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9695_22_28_51.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9696_22_28_51.txt
#   inflating: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9697_22_28_51.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9698_22_28_51.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9699_22_28_51.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_969_22_12_41.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9700_22_28_52.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9701_22_28_52.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9702_22_28_52.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9703_22_28_52.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9704_22_28_52.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9705_22_28_52.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9706_22_28_52.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9707_22_28_52.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9708_22_28_52.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9709_22_28_53.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_970_22_12_41.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9710_22_28_53.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9711_22_28_53.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9712_22_28_53.txt
#   inflating: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9713_22_28_53.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9714_22_28_53.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9715_22_28_53.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_971_22_12_41.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_972_22_12_41.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_973_22_12_41.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_974_22_12_41.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_975_22_12_42.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_976_22_12_42.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_977_22_12_42.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_978_22_12_42.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_979_22_12_42.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_980_22_12_42.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_981_22_12_42.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_982_22_12_42.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_983_22_12_42.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_984_22_12_43.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_985_22_12_43.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_986_22_12_43.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_987_22_12_43.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_988_22_12_43.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_989_22_12_43.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_990_22_12_43.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_991_22_12_43.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_992_22_12_43.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_993_22_12_44.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_994_22_12_44.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_995_22_12_44.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9967_22_29_21.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9968_22_29_21.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9969_22_29_22.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_996_22_12_44.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9970_22_29_22.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9971_22_29_22.txt
#   inflating: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9972_22_29_22.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9973_22_29_22.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9974_22_29_22.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9975_22_29_22.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9976_22_29_22.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9977_22_29_22.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9978_22_29_23.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9979_22_29_23.txt
#   inflating: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_997_22_12_44.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9980_22_29_23.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9981_22_29_23.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9982_22_29_23.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9983_22_29_23.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9984_22_29_23.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9985_22_29_23.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9986_22_29_23.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9987_22_29_24.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9988_22_29_24.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9989_22_29_24.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_998_22_12_44.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9990_22_29_24.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9991_22_29_24.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9992_22_29_24.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9993_22_29_24.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9994_22_29_24.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9995_22_29_24.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9996_22_29_25.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9997_22_29_25.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9998_22_29_25.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_9999_22_29_25.txt
#  extracting: /content/DEV[95%]/unit1/camera_data_bbox/image_BS2_999_22_12_44.txt

# %%
# !pip install pytorch_model_summary

# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
import os
import copy
import torch
from torch.utils.data import Dataset
import ast
import torch.nn as nn
import torch.nn.functional as F
from collections import OrderedDict
from torch.utils.data import DataLoader
from torch.utils.tensorboard import SummaryWriter
from pytorch_model_summary import summary
import sys
import datetime
from scipy.io import savemat
from collections import OrderedDict

# %%
## 序列生成
## Sequence Generator

# 阻塞预测函数
def blockage_prediction(csv_frame, data_list_y):
    data_label = np.empty((0, 1), dtype=int)
    for i in np.arange(len(data_list_y)):
        blockage = np.zeros(data_list_y[0])
        for j in range(len(data_list_y[i])):
            blockage[j] = csv_frame[csv_frame.index == data_list_y[i][j]]['blockage'].item()
        blockage = np.sum(blockage) > 0
        data_label = np.append(data_label, blockage)
    return data_label

# 波束预测函数：该函数的目标是预测 给定 时刻或给定数据条件下最合适的波束索引
def beam_prediction(csv_frame, data_list_y):
    data_label = np.empty((0, 1), dtype=int)
    for i in tqdm(np.arange(len(data_list_y))):
        power_levels = np.loadtxt(csv_frame[csv_frame.index == data_list_y[i][0]]['unit1_pwr_60ghz'].item())
        beam_idx = np.argmax(power_levels) + 1
        data_label = np.append(data_label, beam_idx)
    return data_label

# 波束追踪函数：该函数的目标是追踪 多个 时刻或多个位置下的波束选择，并且追踪的是一个时间序列或多个索引对应的波束
def beam_tracking(csv_frame, data_list_y):
    data_label = np.empty((len(data_list_y), len(data_list_y[0])), dtype=int)
    base_path = '/content/scenario8/unit1/mmWave_data/'
    for i in tqdm(np.arange(len(data_list_y))):
        beam_idx = np.zeros(len(data_list_y[0]))
        for j in range(len(data_list_y[i])):
            file_name = csv_frame[csv_frame.index == data_list_y[i][j]]['unit1_pwr_60ghz'].item()
            power_levels =  os.path.join(base_path, file_name)
            beam_idx[j] = np.argmax(power_levels) + 1
        data_label[i] = beam_idx
    return data_label


class TimeSeriesGenerator:
    def __init__(self,
                 csv_file='scenario8.csv',
                 x_size=5,
                 y_size=1,
                 delay=0,
                 seed=5,
                 label_function=beam_prediction,
                 save_filename=None):

        # x_size: Size of input samples
        # y_size: Size of label samples to generate the labels
        # delay: The number of samples between x and y sequences.

        # Example Series: x_size=3, y_size=1, delay=0 --> [1 2 3] [4]
        # Example Series: x_size=3, y_size=1, delay=1 --> [1 2 3] [5]
        # Example Series: x_size=3, y_size=2, delay=0 --> [1 2 3] [4, 5]

        # For Beam Prediction, y_size=1
        # For Blockage Prediction, y_size=# of samples in a blockage duration (e.g., 3 samples)

        if save_filename == None:
            self.save_filename = csv_file.split('.')[0] + '_series' + '.csv'
        else:
            self.save_filename = save_filename

        self.csv_frame = pd.read_csv(csv_file, index_col='index')
        self.num_sequences = self.csv_frame['seq_index'].max()

        self.seq_start = []
        self.seq_end = []
        self._extract_seq_start_end()

        self.x_size = x_size
        self.y_size = y_size
        self.delay = delay

        self.data_list_x = np.empty((0, x_size), dtype=int)
        self.data_list_y = np.empty((0, y_size), dtype=int)
        self.data_list_seq = np.empty((0, y_size), dtype=int)

        self._generate_indices()

        self.data_labels = label_function(self.csv_frame, self.data_list_y)

        # Shuffling indices
        self.num_datapoints = len(self.data_list_y)
        self.data_idx = np.arange(self.num_datapoints)
        rng = np.random.default_rng(seed)
        rng.shuffle(self.data_idx)

        # Shuffling sequences
        self.seq_idx = np.arange(self.num_sequences)
        rng = np.random.default_rng(seed)
        rng.shuffle(self.seq_idx)

    def _extract_seq_start_end(self):
        for i in np.arange(self.num_sequences) + 1:
            data_indices = self.csv_frame[self.csv_frame['seq_index'] == i].index
            self.seq_start.append(data_indices.min())
            self.seq_end.append(data_indices.max())

    def _generate_indices(self):
        for i in range(len(self.seq_start)):
            x_start_ind = self.seq_start[i]
            x_end_ind = x_start_ind + self.x_size

            y_start_ind = x_end_ind + self.delay
            y_end_ind = y_start_ind + self.y_size

            while y_end_ind <= self.seq_end[i] + 1:
                self.data_list_x = np.vstack((self.data_list_x, np.arange(x_start_ind, x_end_ind)))
                self.data_list_y = np.vstack((self.data_list_y, np.arange(y_start_ind, y_end_ind)))
                self.data_list_seq = np.append(self.data_list_seq, i)
                x_start_ind += 1
                x_end_ind += 1
                y_start_ind += 1
                y_end_ind += 1

    def take(self, num_of_data):
        new_dataset = copy.copy(self)
        new_dataset.data_idx = new_dataset.data_idx[:num_of_data]
        new_dataset.num_datapoints = len(new_dataset.data_idx)
        return new_dataset

    def skip(self, num_of_data):
        new_dataset = copy.copy(self)
        new_dataset.data_idx = new_dataset.data_idx[num_of_data:]
        new_dataset.num_datapoints = len(new_dataset.data_idx)
        return new_dataset

    def take_by_idx(self, idx):
        new_dataset = copy.copy(self)
        new_dataset.data_idx = new_dataset.data_idx[idx]
        new_dataset.num_datapoints = len(new_dataset.data_idx)
        return new_dataset

    def __len__(self):
        return self.num_datapoints

    def save_split_files(self, split=(0.7, 0.2, 0.1), data_path_csv_column=None, label_path_csv_column=None,
                         split_names=('train', 'val', 'test'), label_name='beam_index', sequence_split=False,
                         save_y_ind=False):
        if sequence_split:
            num_sequences = self.num_sequences
            num_train = int(num_sequences * split[0])
            num_val = int(num_sequences * split[1])
            idx_train = np.where(np.in1d(self.data_list_seq[self.data_idx], self.seq_idx[:num_train]))
            idx_val = np.where(np.in1d(self.data_list_seq[self.data_idx], self.seq_idx[num_train:num_train + num_val]))
            idx_test = np.where(np.in1d(self.data_list_seq[self.data_idx], self.seq_idx[num_train + num_val:]))


        else:
            # Train, Validation, Test
            num_datapoints = len(self)
            num_train = int(num_datapoints * split[0])
            num_val = int(num_datapoints * split[1])
            idx_train = np.arange(0, num_train)
            idx_val = np.arange(num_train, num_train + num_val)
            idx_test = np.arange(num_train + num_val, num_datapoints)

        idx_list = [idx_train, idx_val, idx_test]
        for n, name in enumerate(split_names):
            self.take_by_idx(idx_list[n]).save_file(file_tag=name, data_path_csv_column=data_path_csv_column,
                                                    label_path_csv_column=label_path_csv_column, label_name=label_name,
                                                    shuffled=True, save_y_ind=save_y_ind)
        '''
        self.take_by_idx(idx_train).save_file(file_tag=split_names[0], data_path_csv_column=data_path_csv_column, label_path_csv_column=label_path_csv_column, label_name=label_name, shuffled=True, save_y_ind=False)
        self.take_by_idx(idx_val).save_file(file_tag=split_names[1], data_path_csv_column=data_path_csv_column, label_path_csv_column=label_path_csv_column, label_name=label_name, shuffled=True, save_y_ind=False)
        self.take_by_idx(idx_test).save_file(file_tag=split_names[2], data_path_csv_column=data_path_csv_column, label_path_csv_column=label_path_csv_column, label_name=label_name, shuffled=True,save_y_ind=False)
        '''

    # data_path_csv_column: If the location of the sequences are required
    # in the output csv file, input the name of the csv column
    # (e.g., 'unit1_radar').
    def save_file(self, file_tag='', data_path_csv_column=None, label_path_csv_column=None, label_name='label',
                  shuffled=False, save_y_ind=False):
        if data_path_csv_column is None:
            df_x = pd.DataFrame(self.data_list_x, columns=['x_%i' % (i + 1) for i in range(self.x_size)])
        else:
            df_x = pd.DataFrame(self.csv_frame[data_path_csv_column].to_numpy(str)[self.data_list_x - 1],
                                columns=['x_%i' % (i + 1) for i in range(self.x_size)])
        if save_y_ind:
            if label_path_csv_column is None:
                df_y = pd.DataFrame(self.data_list_y, columns=['y_%i' % (i + 1) for i in range(self.y_size)])
            else:
                df_y = pd.DataFrame(self.csv_frame[label_path_csv_column].to_numpy(str)[self.data_list_y - 1],
                                    columns=['y_%i' % (i + 1) for i in range(self.y_size)])
        else:
            df_y = pd.DataFrame()
        df_label = pd.DataFrame(self.data_labels,
                                columns=['%s_%i' % (label_name, i + 1) for i in range(self.data_labels.shape[1])])
        df = pd.concat([df_x, df_y, df_label], axis=1)
        df.index.name = 'index'
        df.index += 1

        if shuffled:
            df = df.iloc[self.data_idx]
            df.index.name = 'data_index'
            df = df.reset_index()
            df.index.name = 'index'
            df.index += 1

        filename = self.save_filename.split('.')[0] + '_' + file_tag + '.csv'
        df.to_csv(filename)
        print('%i data points are saved to %s' % (len(df), filename))


# %% Generate Time Series & Save Series CSV Files

csv_file = '/content/DEV[95%]/scenario8.csv'

# May define your own label extraction function if needed
# blockage_prediction and beam_prediction are currently available
label_function = beam_tracking

# Data sequence size
x_size = 8
# Label sequence size, beam_prediction --> 1, blockage_prediction --> 3
y_size = x_size + 5
# Delay
delay = -x_size

rng_seed = 5  # Reproducibility

# The file name will be included in the series
data_path_csv_column = 'unit1_rgb'
label_path_csv_column = 'unit1_pwr_60ghz'
save_y_ind = True
# Name of the labels
label_name = 'beam_index'

# Sequence or data split of the files
# If False, the data is fully shuffled
# If True, Train-Validation-Test sets are separated by the sequence
# i.e., any of the sets will not have a shared sequence
sequence_split = True

x = TimeSeriesGenerator(csv_file=csv_file,
                        x_size=x_size,
                        y_size=y_size,
                        seed=rng_seed,
                        delay=delay,
                        label_function=label_function,
                        save_filename='/content/DEV[95%]/scenario8_series.csv')

x.save_file(file_tag='full', data_path_csv_column=data_path_csv_column, label_path_csv_column=label_path_csv_column,
            label_name=label_name, shuffled=False, save_y_ind=save_y_ind)
x.save_split_files(split=(0.8, 0.0, 0.2), data_path_csv_column=data_path_csv_column,
                   label_path_csv_column=label_path_csv_column, label_name=label_name, sequence_split=sequence_split,
                   save_y_ind=save_y_ind)
# Out:
# 100%|██████████| 3048/3048 [00:11<00:00, 262.79it/s]
# 3048 data points are saved to /content/DEV[95%]/scenario8_series_full.csv
# 2435 data points are saved to /content/DEV[95%]/scenario8_series_train.csv
# 0 data points are saved to /content/DEV[95%]/scenario8_series_val.csv
# 613 data points are saved to /content/DEV[95%]/scenario8_series_test.csv

# %%
## Pre-Processing

def preprocess(in_path, out_path):
    base_path = '/content/DEV[95%]'
    csv_file_path = in_path
    csv_save_path = out_path
    df = pd.read_csv(csv_file_path)

    cols1 = ['x_'+str(s) for s in range(1,9)]
    cols2 = ['y_'+str(s) for s in range(1,14)]
    for index, row in tqdm(df.iterrows(), total=df.shape[0]):
        for c in cols1:
            relative_path = row.loc[c]
            relative_path = relative_path.replace('camera_data', 'camera_data_bbox').replace('jpg', 'txt')
            full_path = os.path.join(base_path, relative_path)
            path = os.path.normpath(os.path.join(base_path, relative_path.lstrip('./')))
            try:
                content = np.loadtxt(path)[1:]
            except:
                content = np.zeros(4)
            if not content.size:
                content = np.zeros(4)
            df.at[index, c] = np.array2string(content, separator=',')
        for c in cols2:
            relative_path = row.loc[c]
            path = os.path.normpath(os.path.join(base_path, relative_path.lstrip('./')))
            content = np.loadtxt(path)
            df.at[index, c] = np.array2string(content, separator=',')

    df.to_csv(csv_save_path, index=False)


#%% training dataset
csv_file_path = '/content/DEV[95%]/scenario8_series_train.csv'
csv_save_path = '/content/DEV[95%]/scenario8_series_bbox_train.csv'
preprocess(csv_file_path, csv_save_path)

#%% test dataset
csv_file_path = '/content/DEV[95%]/scenario8_series_test.csv'
csv_save_path = '/content/DEV[95%]/scenario8_series_bbox_test.csv'
preprocess(csv_file_path, csv_save_path)
# Out:
# 100%|██████████| 2435/2435 [00:36<00:00, 66.33it/s]
#  40%|███▉      | 245/613 [00:03<00:05, 70.04it/s]<ipython-input-4-9a580f9e3b4f>:19: UserWarning: loadtxt: input contained no data: "/content/DEV[95%]/unit1/camera_data_bbox/image_BS2_607_22_12_01.txt"
#   content = np.loadtxt(path)[1:]
# <ipython-input-4-9a580f9e3b4f>:19: UserWarning: loadtxt: input contained no data: "/content/DEV[95%]/unit1/camera_data_bbox/image_BS2_608_22_12_01.txt"
#   content = np.loadtxt(path)[1:]
# 100%|██████████| 613/613 [00:09<00:00, 63.99it/s]

# %%
## Data Feeder

def create_samples(root, portion=1.0, num_beam=64):
    f = pd.read_csv(root)
    bbox_all = []
    beam_power_all = []
    for idx, row in f.iterrows():
        bboxes = np.stack(
            [np.asarray(ast.literal_eval(r)) for r in row.loc["x_1":"x_8"]], axis=0
        )
        bbox_all.append(bboxes)
        beam_powers = np.stack(
            [np.asarray(ast.literal_eval(r)) for r in row.loc["y_1":"y_13"]], axis=0
        )
        beam_power_all.append(beam_powers)

    bbox_all = np.stack(bbox_all, axis=0)
    beam_power_all = np.stack(beam_power_all, axis=0)
    best_beam = np.argmax(beam_power_all, axis=-1)

    print("list is ready")
    num_data = len(beam_power_all)
    num_data = int(num_data * portion)
    return bbox_all[:num_data], best_beam[:num_data, -5:]


class DataFeed(Dataset):
    def __init__(self, root_dir, portion=1.0, num_beam=64):

        self.root = root_dir
        self.samples, self.pred_val = create_samples(
            self.root, portion=portion, num_beam=num_beam
        )
        self.seq_len = 8
        self.num_beam = num_beam

    def __len__(self):
        return len(self.samples)

    def __getitem__(self, idx):
        samples = self.samples[idx]  # Read one data sample
        pred_val = self.pred_val[idx]

        samples = samples[-self.seq_len :]  # Read a sequence of tuples from a sample

        out_beam = torch.zeros((5,))
        bbox = torch.zeros((self.seq_len, 4))

        if not samples.size:
            samples = np.zeros(4)
        bbox = torch.tensor(samples, requires_grad=False)

        out_beam = torch.tensor(pred_val, requires_grad=False)

        return bbox.float(), out_beam.long()

# %%
## Model

class GruModelSimple(nn.Module):
    def __init__(self, num_classes, num_layers=3, hidden_size=64, embed_size=64):
        super(GruModelSimple, self).__init__()
        self.embed = torch.nn.Linear(4, embed_size)
        self.num_layers = num_layers
        self.hidden_size = hidden_size
        self.gru = torch.nn.GRU(
            input_size=embed_size,
            hidden_size=hidden_size,
            num_layers=num_layers,
            dropout=0.3,
        )
        self.fc = torch.nn.Linear(hidden_size, num_classes)
        self.name = "GruModelSimple"
        self.dropout1 = nn.Dropout(0.5)

    def initHidden(self, batch_size):
        return torch.zeros((self.num_layers, batch_size, self.hidden_size))

    def forward(self, x, h):
        y = self.embed(x)
        y = self.dropout1(y)
        y, h = self.gru(y, h)
        y = self.fc(y)
        return y, h

# %%
## Training

def train_model(num_epoch=100, if_writer=False, portion=1.0, num_beam=64):
    num_classes = num_beam + 1
    batch_size = 8
    val_batch_size = 64
    train_dir = "/content/DEV[95%]/scenario8_series_bbox_train.csv"
    val_dir = "/content/DEV[95%]/scenario8_series_bbox_test.csv"
    train_loader = DataLoader(
        DataFeed(train_dir, num_beam=num_beam), batch_size=batch_size, shuffle=True
    )
    val_loader = DataLoader(
        DataFeed(val_dir, num_beam=num_beam), batch_size=val_batch_size, shuffle=False
    )

    # check gpu acceleration availability
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(device)

    now = datetime.datetime.now().strftime("%H_%M_%S")
    date = datetime.date.today().strftime("%y_%m_%d")

    # Instantiate the model
    net = GruModelSimple(num_classes)
    # path to save the model
    checkpoint_dir = "./checkpoint/"
    os.makedirs(checkpoint_dir, exist_ok=True)

    PATH = os.path.join(checkpoint_dir, f"{now}_{date}_{net.name}.pth")
    #PATH = "./checkpoint/" + now + "_" + date + "_" + net.name + "" + ".pth"
    # print model summary
    if if_writer:
        h = net.initHidden(1)
        print(summary(net, torch.zeros((8, 1, 4)), h))
    # send model to GPU
    net.to(device)

    # set up loss function and optimizer
    criterion = nn.CrossEntropyLoss()
    optimizer = torch.optim.Adam(net.parameters(), lr=0.001)
    scheduler = torch.optim.lr_scheduler.MultiStepLR(
        optimizer, milestones=[10, 30, 50], gamma=0.1)
    if if_writer:
        writer = SummaryWriter(comment=now + "_" + date + "_" + net.name)
        # writer.add_graph(net, (torch.zeros((1, 1, 1024)), torch.zeros((1, 1, 1024))))

    # train model
    val_top1_acc_his = []
    val_top2_acc_his = []
    val_top3_acc_his = []
    val_top5_acc_his = []

    for epoch in range(num_epoch):  # loop over the dataset multiple times
        net.train()
        running_loss = 0.0
        running_acc = 1.0
        with tqdm(train_loader, unit="batch", file=sys.stdout) as tepoch:
            for i, (bbox, label) in enumerate(tepoch, 0):
                tepoch.set_description(f"Epoch {epoch}")
                # get the input np arrays, bbox sequence (batch_size, 8, 4) label (batch_size, 1)
                #bbox = (bbox - bbox.mean(dim=1, keepdim=True)) / bbox.std(dim=1, keepdim=True)
                bbox = torch.swapaxes(bbox, 0, 1)
                bbox = torch.cat(
                    [bbox, torch.zeros(torch.Size((4,)) + bbox.shape[1:]) - 1], dim=0
                )
                label = torch.swapaxes(label, 0, 1)
                bbox = bbox.to(device)
                label = label.to(device)
                optimizer.zero_grad()

                h = net.initHidden(bbox.shape[1]).to(device)
                outputs, _ = net(bbox, h)
                outputs = outputs[-5:, ...]
                loss = criterion(outputs.view(-1, num_classes), label.flatten())
                prediction = torch.argmax(outputs, dim=-1)
                acc = (prediction == label).sum().item() / int(
                    torch.sum(label != -100).cpu()
                )
                loss.backward()
                optimizer.step()
                # print statistics
                running_loss = (loss.item() + i * running_loss) / (i + 1)
                running_acc = (acc + i * running_acc) / (i + 1)
                log = OrderedDict()
                log["loss"] = running_loss
                log["acc"] = running_acc
                tepoch.set_postfix(log)
            scheduler.step()
            # validation
            predictions = []
            net.eval()
            with torch.no_grad():
                total = np.zeros((5,))
                top1_correct = np.zeros((5,))
                top2_correct = np.zeros((5,))
                top3_correct = np.zeros((5,))
                top5_correct = np.zeros((5,))

                val_loss = 0
                for (bbox, label) in val_loader:
                    bbox = torch.swapaxes(bbox, 0, 1)
                    #bbox = (bbox - bbox.mean(dim=1, keepdim=True)) / bbox.std(dim=1, keepdim=True)
                    bbox = torch.cat(
                        [bbox, torch.zeros(torch.Size((4,)) + bbox.shape[1:]) - 1],
                        dim=0,
                    )
                    label = torch.swapaxes(label, 0, 1)
                    bbox = bbox.to(device)
                    label = label.to(device)
                    optimizer.zero_grad()

                    h = net.initHidden(bbox.shape[1]).to(device)
                    outputs, _ = net(bbox, h)
                    outputs = outputs[-5:, ...]
                    label = label[-5:, ...]
                    val_loss += nn.CrossEntropyLoss(reduction="sum")(
                        outputs.view(-1, num_classes), label.flatten()
                    ).item()
                    total += torch.sum(label != -100, dim=-1).cpu().numpy()
                    prediction = torch.argmax(outputs, dim=-1)
                    top1_correct += torch.sum(prediction == label, dim=-1).cpu().numpy()
                    _, idx = torch.topk(outputs, 5, dim=-1)
                    idx = idx.cpu().numpy()
                    idx = np.minimum(idx, num_beam - 1)
                    label = label.cpu().numpy()
                    for i in range(label.shape[0]):
                        for j in range(label.shape[1]):
                            top2_correct[i] += np.isin(label[i, j], idx[i, j, :2]).sum()
                            top3_correct[i] += np.isin(label[i, j], idx[i, j, :3]).sum()
                            top5_correct[i] += np.isin(label[i, j], idx[i, j, :5]).sum()

                    predictions.append(prediction.cpu().numpy())

                val_loss /= total.sum()
                #scheduler.step(val_loss)
                val_top1_acc = top1_correct / total
                val_top2_acc = top2_correct / total
                val_top3_acc = top3_correct / total
                val_top5_acc = top5_correct / total

                print("val_loss={:.4f}".format(val_loss), flush=True)
                print("accuracy", flush=True)
                print(
                    np.stack(
                        [val_top1_acc, val_top2_acc, val_top3_acc, val_top5_acc], 0
                    ),
                    flush=True,
                )
                print("power", flush=True)
        if if_writer:
            writer.add_scalar("Loss/train", running_loss, epoch)
            writer.add_scalar("Loss/test", val_loss, epoch)
            writer.add_scalar("acc/train", running_acc, epoch)
            writer.add_scalar("acc/test", val_top1_acc[0], epoch)
        val_top1_acc_his.append(val_top1_acc)
        val_top2_acc_his.append(val_top2_acc)
        val_top3_acc_his.append(val_top3_acc)
        val_top5_acc_his.append(val_top5_acc)

    if if_writer:
        writer.close()
        torch.save(net.state_dict(), PATH)

    his = {
        "acc_top1": val_top1_acc_his,
        "acc_top2": val_top2_acc_his,
        "acc_top3": val_top3_acc_his,
        "acc_top5": val_top5_acc_his,
    }
    print("Finished Training")

    # load the model
    net.to(device)
    net.eval()
    # test
    predictions = []
    raw_predictions = []
    net.eval()
    with torch.no_grad():
        total = np.zeros((5,))
        top1_correct = np.zeros((5,))
        top2_correct = np.zeros((5,))
        top3_correct = np.zeros((5,))
        top5_correct = np.zeros((5,))
        val_loss = 0
        for (bbox, label) in val_loader:
            bbox = torch.swapaxes(bbox, 0, 1)
            bbox = torch.cat(
                [bbox, torch.zeros(torch.Size((4,)) + bbox.shape[1:]) - 1], dim=0
            )
            label = torch.swapaxes(label, 0, 1)
            bbox = bbox.to(device)
            label = label.to(device)

            bbox = bbox.to(device)
            label = label.to(device)

            h = net.initHidden(bbox.shape[1]).to(device)
            outputs, _ = net(bbox, h)
            outputs = outputs[-5:, ...]
            label = label[-5:, ...]
            val_loss += nn.CrossEntropyLoss(reduction="sum")(
                outputs.view(-1, num_classes), label.flatten()
            ).item()
            total += torch.sum(label != -100, dim=-1).cpu().numpy()
            prediction = torch.argmax(outputs, dim=-1)
            top1_correct += torch.sum(prediction == label, dim=-1).cpu().numpy()

            _, idx = torch.topk(outputs, 5, dim=-1)
            idx = idx.cpu().numpy()
            label = label.cpu().numpy()
            for i in range(label.shape[0]):
                for j in range(label.shape[1]):
                    top2_correct[i] += np.isin(label[i, j], idx[i, j, :2]).sum()
                    top3_correct[i] += np.isin(label[i, j], idx[i, j, :3]).sum()
                    top5_correct[i] += np.isin(label[i, j], idx[i, j, :5]).sum()

            predictions.append(prediction.cpu().numpy())
            raw_predictions.append(outputs.cpu().numpy())

        val_loss /= total.sum()
        val_top1_acc = top1_correct / total
        val_top2_acc = top2_correct / total
        val_top3_acc = top3_correct / total
        val_top5_acc = top5_correct / total

        predictions = np.concatenate(predictions, 1)
        raw_predictions = np.concatenate(raw_predictions, 1)

        val_acc = {
            "top1": val_top1_acc,
            "top2": val_top2_acc,
            "top3": val_top3_acc,
            "top5": val_top5_acc,
        }
        return val_loss, val_acc, predictions, raw_predictions, his


if __name__ == "__main__":
    torch.manual_seed(42)
    num_epoch = 100
    val_loss, val_acc, predictions, raw_predictions, his = train_model(
        num_epoch=num_epoch, if_writer=True, portion=1.0, num_beam=64
    )
    print(val_acc)

    plot_dir = "./plot"
    os.makedirs(plot_dir, exist_ok=True)

    file_path = os.path.join(plot_dir, "test_acc.mat")
    savemat(file_path, {'test_acc': val_acc})
    print(f"Results saved at: {file_path}")

    savemat('plot/test_acc.mat',{'test_acc':val_acc})
# Out:
# list is ready
# list is ready
# cuda
# ------------------------------------------------------------------------------
#       Layer (type)               Output Shape         Param #     Tr. Param #
# ==============================================================================
#           Linear-1                 [8, 1, 64]             320             320
#          Dropout-2                 [8, 1, 64]               0               0
#              GRU-3     [8, 1, 64], [3, 1, 64]          74,880          74,880
#           Linear-4                 [8, 1, 65]           4,225           4,225
# ==============================================================================
# Total params: 79,425
# Trainable params: 79,425
# Non-trainable params: 0
# ------------------------------------------------------------------------------
# Epoch 0: 100%|██████████| 305/305 [00:04<00:00, 70.95batch/s, loss=2.88, acc=0.226]
# val_loss=2.2965
# accuracy
# [[0.28548124 0.30342577 0.31810767 0.31484502 0.3050571 ]
#  [0.42577488 0.45513866 0.48287113 0.50897227 0.51223491]
#  [0.51712887 0.54649266 0.57422512 0.59216966 0.60195759]
#  [0.69331158 0.71288744 0.72593801 0.73409462 0.7324633 ]]
# power
# Epoch 1: 100%|██████████| 305/305 [00:03<00:00, 94.23batch/s, loss=2.13, acc=0.332]
# val_loss=1.9751
# accuracy
# [[0.35725938 0.36867863 0.3817292  0.37357259 0.33442088]
#  [0.54323002 0.55301794 0.55954323 0.56117455 0.55628059]
#  [0.65742251 0.67047308 0.67536705 0.65905383 0.63947798]
#  [0.78955954 0.80261011 0.80587276 0.79934747 0.76182708]]
# power
# Epoch 2: 100%|██████████| 305/305 [00:03<00:00, 96.53batch/s, loss=1.92, acc=0.358]
# val_loss=1.8735
# accuracy
# [[0.37520392 0.38336052 0.37846656 0.36867863 0.33931485]
#  [0.52365416 0.54323002 0.55954323 0.56117455 0.54323002]
#  [0.67047308 0.69657423 0.71125612 0.69331158 0.65905383]
#  [0.82218597 0.84013051 0.85154976 0.84665579 0.80097879]]
# power
# Epoch 3: 100%|██████████| 305/305 [00:03<00:00, 91.31batch/s, loss=1.79, acc=0.387]
# val_loss=1.7254
# accuracy
# [[0.41598695 0.4274062  0.4274062  0.41272431 0.40130506]
#  [0.60195759 0.62805873 0.63132137 0.62479608 0.58727569]
#  [0.71451876 0.73898858 0.74551387 0.73572594 0.69331158]
#  [0.84502447 0.85644372 0.862969   0.84828711 0.82381729]]
# power
# Epoch 4: 100%|██████████| 305/305 [00:03<00:00, 89.07batch/s, loss=1.74, acc=0.394]
# val_loss=1.5519
# accuracy
# [[0.49755302 0.49102773 0.46818923 0.4502447  0.43393148]
#  [0.68515498 0.6949429  0.69983687 0.70146819 0.69331158]
#  [0.78303426 0.79934747 0.80261011 0.80424144 0.79445351]
#  [0.92169657 0.9314845  0.93637847 0.93964111 0.93474715]]
# power
# Epoch 5: 100%|██████████| 305/305 [00:03<00:00, 99.76batch/s, loss=1.69, acc=0.407]
# val_loss=1.5457
# accuracy
# [[0.43066884 0.45513866 0.46166395 0.4502447  0.43066884]
#  [0.63947798 0.65252855 0.65905383 0.66557912 0.64274062]
#  [0.78792822 0.80587276 0.80750408 0.79119086 0.77814029]
#  [0.93800979 0.95106036 0.94779772 0.94453507 0.91680261]]
# power
# Epoch 6: 100%|██████████| 305/305 [00:03<00:00, 92.70batch/s, loss=1.65, acc=0.413]
# val_loss=1.6481
# accuracy
# [[0.38499184 0.39314845 0.39151713 0.39314845 0.41272431]
#  [0.5725938  0.57911909 0.58401305 0.60032626 0.62479608]
#  [0.7096248  0.70636215 0.70473083 0.71941272 0.75203915]
#  [0.90701468 0.89885808 0.89722675 0.89396411 0.91190865]]
# power
# Epoch 7: 100%|██████████| 305/305 [00:03<00:00, 81.35batch/s, loss=1.58, acc=0.429]
# val_loss=1.5556
# accuracy
# [[0.43230016 0.4502447  0.44045677 0.44698206 0.40619902]
#  [0.65579119 0.67699837 0.6867863  0.67373573 0.63621533]
#  [0.79608483 0.81239804 0.81076672 0.80261011 0.75856444]
#  [0.9314845  0.93800979 0.94127243 0.9233279  0.89070147]]
# power
# Epoch 8: 100%|██████████| 305/305 [00:03<00:00, 95.34batch/s, loss=1.59, acc=0.423]
# val_loss=1.5113
# accuracy
# [[0.46982055 0.47634584 0.46003263 0.43556281 0.39477977]
#  [0.70799347 0.70636215 0.68352365 0.66884176 0.63458401]
#  [0.84991843 0.8548124  0.84013051 0.82218597 0.80097879]
#  [0.94942904 0.954323   0.95595432 0.95269168 0.93964111]]
# power
# Epoch 9: 100%|██████████| 305/305 [00:03<00:00, 99.19batch/s, loss=1.54, acc=0.433]
# val_loss=1.3575
# accuracy
# [[0.50081566 0.5187602  0.50897227 0.48613377 0.46003263]
#  [0.7324633  0.74551387 0.74551387 0.72430669 0.72430669]
#  [0.88091354 0.87601958 0.86623165 0.85644372 0.84828711]
#  [0.96247961 0.96574225 0.96737357 0.96900489 0.95595432]]
# power
# Epoch 10: 100%|██████████| 305/305 [00:03<00:00, 88.83batch/s, loss=1.47, acc=0.458]
# val_loss=1.3527
# accuracy
# [[0.50570962 0.51386623 0.50897227 0.48613377 0.45676998]
#  [0.75530179 0.75856444 0.74714519 0.73572594 0.71288744]
#  [0.87112561 0.87928222 0.86949429 0.85644372 0.82544861]
#  [0.96411093 0.96247961 0.96900489 0.96737357 0.95106036]]
# power
# Epoch 11: 100%|██████████| 305/305 [00:03<00:00, 82.21batch/s, loss=1.48, acc=0.453]
# val_loss=1.3292
# accuracy
# [[0.5187602  0.53507341 0.53017945 0.50244698 0.46655791]
#  [0.77324633 0.77977162 0.76835237 0.75367047 0.72756933]
#  [0.88091354 0.88907015 0.8858075  0.86623165 0.83849918]
#  [0.96900489 0.96737357 0.96900489 0.96411093 0.95269168]]
# power
# Epoch 12: 100%|██████████| 305/305 [00:03<00:00, 97.38batch/s, loss=1.47, acc=0.454]
# val_loss=1.3559
# accuracy
# [[0.50244698 0.51386623 0.50244698 0.4812398  0.44861338]
#  [0.73572594 0.76182708 0.75367047 0.73409462 0.70309951]
#  [0.87438825 0.87112561 0.87275693 0.8548124  0.81892333]
#  [0.96247961 0.96247961 0.96737357 0.96574225 0.94779772]]
# power
# Epoch 13: 100%|██████████| 305/305 [00:03<00:00, 99.27batch/s, loss=1.47, acc=0.456]
# val_loss=1.3417
# accuracy
# [[0.50897227 0.51386623 0.51386623 0.47960848 0.46166395]
#  [0.75040783 0.7634584  0.74388254 0.74388254 0.71125612]
#  [0.8776509  0.88254486 0.87601958 0.86460033 0.82871126]
#  [0.96574225 0.96574225 0.96574225 0.96737357 0.94616639]]
# power
# Epoch 14: 100%|██████████| 305/305 [00:03<00:00, 88.62batch/s, loss=1.46, acc=0.456]
# val_loss=1.3290
# accuracy
# [[0.53344209 0.53996737 0.52854812 0.5040783  0.47145188]
#  [0.76672104 0.77161501 0.76835237 0.75530179 0.72756933]
#  [0.8858075  0.88907015 0.8858075  0.85807504 0.84502447]
#  [0.96737357 0.96737357 0.97063622 0.96574225 0.95595432]]
# power
# Epoch 15: 100%|██████████| 305/305 [00:03<00:00, 85.95batch/s, loss=1.47, acc=0.456]
# val_loss=1.3326
# accuracy
# [[0.53181077 0.53181077 0.53344209 0.50570962 0.47471452]
#  [0.76508972 0.76019576 0.75856444 0.73409462 0.72920065]
#  [0.8858075  0.88417618 0.87112561 0.8548124  0.85154976]
#  [0.96411093 0.96574225 0.96900489 0.96737357 0.95758564]]
# power
# Epoch 16: 100%|██████████| 305/305 [00:03<00:00, 97.22batch/s, loss=1.45, acc=0.458]
# val_loss=1.3147
# accuracy
# [[0.53017945 0.54159869 0.53017945 0.50734095 0.48450245]
#  [0.77650897 0.76019576 0.75530179 0.74388254 0.75040783]
#  [0.8858075  0.89070147 0.87601958 0.85644372 0.85318108]
#  [0.96574225 0.96574225 0.96900489 0.96737357 0.95758564]]
# power
# Epoch 17: 100%|██████████| 305/305 [00:03<00:00, 93.02batch/s, loss=1.45, acc=0.458]
# val_loss=1.3681
# accuracy
# [[0.48613377 0.49429038 0.49102773 0.46492659 0.44535073]
#  [0.73083197 0.75040783 0.73409462 0.72593801 0.69820555]
#  [0.86623165 0.87112561 0.86623165 0.84991843 0.82055465]
#  [0.96247961 0.96411093 0.96737357 0.96247961 0.93800979]]
# power
# Epoch 18: 100%|██████████| 305/305 [00:03<00:00, 81.11batch/s, loss=1.45, acc=0.461]
# val_loss=1.3112
# accuracy
# [[0.53833605 0.54323002 0.53670473 0.5040783  0.47471452]
#  [0.7634584  0.76508972 0.76998369 0.74551387 0.73083197]
#  [0.88417618 0.88743883 0.88254486 0.86786297 0.84991843]
#  [0.96737357 0.96900489 0.97063622 0.96574225 0.95595432]]
# power
# Epoch 19: 100%|██████████| 305/305 [00:03<00:00, 90.13batch/s, loss=1.43, acc=0.464]
# val_loss=1.3416
# accuracy
# [[0.51060359 0.51549755 0.51386623 0.48939641 0.45840131]
#  [0.75203915 0.75693312 0.74714519 0.7406199  0.70473083]
#  [0.87438825 0.88091354 0.88091354 0.85970636 0.82381729]
#  [0.96247961 0.96737357 0.96900489 0.96084829 0.95269168]]
# power
# Epoch 20: 100%|██████████| 305/305 [00:03<00:00, 101.59batch/s, loss=1.44, acc=0.465]
# val_loss=1.3161
# accuracy
# [[0.51060359 0.5187602  0.51549755 0.49102773 0.46003263]
#  [0.76019576 0.77324633 0.75693312 0.7406199  0.72267537]
#  [0.8776509  0.88091354 0.88254486 0.87275693 0.83849918]
#  [0.96574225 0.96737357 0.97063622 0.96574225 0.95595432]]
# power
# Epoch 21: 100%|██████████| 305/305 [00:03<00:00, 95.76batch/s, loss=1.44, acc=0.461]
# val_loss=1.3169
# accuracy
# [[0.51549755 0.5187602  0.51223491 0.49102773 0.46003263]
#  [0.77324633 0.77161501 0.75367047 0.73898858 0.71615008]
#  [0.88091354 0.88254486 0.88091354 0.862969   0.8319739 ]
#  [0.96411093 0.96900489 0.96900489 0.96574225 0.95269168]]
# power
# Epoch 22: 100%|██████████| 305/305 [00:03<00:00, 80.60batch/s, loss=1.44, acc=0.46]
# val_loss=1.3661
# accuracy
# [[0.50897227 0.49429038 0.4959217  0.47145188 0.43882545]
#  [0.73572594 0.74225122 0.73898858 0.72920065 0.6949429 ]
#  [0.87112561 0.8776509  0.87112561 0.85318108 0.82544861]
#  [0.96084829 0.96574225 0.96737357 0.96574225 0.95269168]]
# power
# Epoch 23: 100%|██████████| 305/305 [00:03<00:00, 89.94batch/s, loss=1.44, acc=0.46]
# val_loss=1.3409
# accuracy
# [[0.51712887 0.51549755 0.50244698 0.48776509 0.45513866]
#  [0.75203915 0.76019576 0.75693312 0.75367047 0.71615008]
#  [0.87438825 0.88254486 0.87438825 0.85644372 0.82871126]
#  [0.96411093 0.96411093 0.96900489 0.95758564 0.94290375]]
# power
# Epoch 24: 100%|██████████| 305/305 [00:03<00:00, 97.70batch/s, loss=1.43, acc=0.461]
# val_loss=1.3047
# accuracy
# [[0.53344209 0.53344209 0.52202284 0.50244698 0.46818923]
#  [0.76998369 0.77814029 0.75530179 0.74877651 0.73083197]
#  [0.88254486 0.8858075  0.88417618 0.87112561 0.85154976]
#  [0.96737357 0.96900489 0.97063622 0.97063622 0.95595432]]
# power
# Epoch 25: 100%|██████████| 305/305 [00:03<00:00, 93.77batch/s, loss=1.44, acc=0.463]
# val_loss=1.3145
# accuracy
# [[0.52854812 0.52202284 0.51060359 0.49102773 0.46003263]
#  [0.76182708 0.77161501 0.7634584  0.74714519 0.71125612]
#  [0.87112561 0.87928222 0.8776509  0.86133768 0.83686786]
#  [0.96574225 0.96900489 0.97553018 0.96737357 0.95595432]]
# power
# Epoch 26: 100%|██████████| 305/305 [00:03<00:00, 80.39batch/s, loss=1.43, acc=0.465]
# val_loss=1.3199
# accuracy
# [[0.52202284 0.52202284 0.51712887 0.49755302 0.45513866]
#  [0.76835237 0.77650897 0.77324633 0.76672104 0.72267537]
#  [0.88091354 0.8858075  0.88417618 0.862969   0.8319739 ]
#  [0.96737357 0.96900489 0.97553018 0.96574225 0.94779772]]
# power
# Epoch 27: 100%|██████████| 305/305 [00:03<00:00, 96.76batch/s, loss=1.43, acc=0.468]
# val_loss=1.3020
# accuracy
# [[0.52528548 0.53344209 0.52365416 0.49429038 0.46818923]
#  [0.78140294 0.77814029 0.76508972 0.75367047 0.73083197]
#  [0.88417618 0.89070147 0.88743883 0.862969   0.8319739 ]
#  [0.96737357 0.96737357 0.97389886 0.96737357 0.95595432]]
# power
# Epoch 28: 100%|██████████| 305/305 [00:03<00:00, 91.27batch/s, loss=1.43, acc=0.464]
# val_loss=1.3038
# accuracy
# [[0.54486134 0.54323002 0.53344209 0.50244698 0.46982055]
#  [0.79608483 0.78466558 0.76672104 0.76019576 0.73572594]
#  [0.88743883 0.89722675 0.89233279 0.87275693 0.85154976]
#  [0.96900489 0.96900489 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 29: 100%|██████████| 305/305 [00:03<00:00, 82.35batch/s, loss=1.42, acc=0.467]
# val_loss=1.3062
# accuracy
# [[0.53181077 0.52202284 0.51549755 0.48776509 0.45840131]
#  [0.76835237 0.76835237 0.75040783 0.73735726 0.72593801]
#  [0.88743883 0.88417618 0.88091354 0.87438825 0.84013051]
#  [0.96574225 0.96737357 0.97389886 0.97226754 0.95595432]]
# power
# Epoch 30: 100%|██████████| 305/305 [00:03<00:00, 83.34batch/s, loss=1.42, acc=0.466]
# val_loss=1.2971
# accuracy
# [[0.53181077 0.53833605 0.5187602  0.50081566 0.47145188]
#  [0.77977162 0.77814029 0.76998369 0.75203915 0.72593801]
#  [0.88417618 0.89233279 0.89070147 0.87438825 0.84339315]
#  [0.96574225 0.96737357 0.97389886 0.97226754 0.95921697]]
# power
# Epoch 31: 100%|██████████| 305/305 [00:03<00:00, 97.25batch/s, loss=1.41, acc=0.47]
# val_loss=1.2996
# accuracy
# [[0.54159869 0.53507341 0.53507341 0.49429038 0.46818923]
#  [0.77650897 0.77977162 0.76998369 0.75856444 0.72104405]
#  [0.8858075  0.89233279 0.88417618 0.86949429 0.84828711]
#  [0.96737357 0.96900489 0.97553018 0.96900489 0.95269168]]
# power
# Epoch 32: 100%|██████████| 305/305 [00:03<00:00, 94.07batch/s, loss=1.4, acc=0.471]
# val_loss=1.3050
# accuracy
# [[0.54159869 0.53017945 0.52202284 0.49265905 0.46655791]
#  [0.77324633 0.78303426 0.77324633 0.7634584  0.72267537]
#  [0.88417618 0.88907015 0.88417618 0.86786297 0.84339315]
#  [0.96737357 0.96737357 0.97553018 0.96900489 0.95269168]]
# power
# Epoch 33: 100%|██████████| 305/305 [00:03<00:00, 80.93batch/s, loss=1.41, acc=0.469]
# val_loss=1.2933
# accuracy
# [[0.53344209 0.53996737 0.53507341 0.49918434 0.46818923]
#  [0.78303426 0.78466558 0.77161501 0.75693312 0.73083197]
#  [0.88743883 0.89396411 0.8858075  0.86949429 0.84176183]
#  [0.96737357 0.97063622 0.9771615  0.97063622 0.95595432]]
# power
# Epoch 34: 100%|██████████| 305/305 [00:03<00:00, 90.57batch/s, loss=1.41, acc=0.467]
# val_loss=1.2991
# accuracy
# [[0.53833605 0.53670473 0.53017945 0.50244698 0.46492659]
#  [0.78140294 0.77814029 0.76835237 0.76182708 0.72104405]
#  [0.88417618 0.89233279 0.88417618 0.87112561 0.84502447]
#  [0.96737357 0.96900489 0.97553018 0.96737357 0.95595432]]
# power
# Epoch 35: 100%|██████████| 305/305 [00:03<00:00, 96.02batch/s, loss=1.42, acc=0.47]
# val_loss=1.2962
# accuracy
# [[0.53670473 0.53996737 0.5269168  0.50244698 0.46982055]
#  [0.77814029 0.78140294 0.77324633 0.75693312 0.72430669]
#  [0.88417618 0.89396411 0.8858075  0.8776509  0.84665579]
#  [0.96737357 0.96900489 0.97553018 0.97063622 0.95758564]]
# power
# Epoch 36: 100%|██████████| 305/305 [00:03<00:00, 95.25batch/s, loss=1.42, acc=0.466]
# val_loss=1.2983
# accuracy
# [[0.53670473 0.53833605 0.52528548 0.49265905 0.46655791]
#  [0.77977162 0.77814029 0.76672104 0.75040783 0.72756933]
#  [0.88417618 0.88907015 0.88743883 0.87275693 0.84502447]
#  [0.96574225 0.96900489 0.97389886 0.96900489 0.95921697]]
# power
# Epoch 37: 100%|██████████| 305/305 [00:02<00:00, 104.30batch/s, loss=1.41, acc=0.472]
# val_loss=1.2965
# accuracy
# [[0.53344209 0.53833605 0.5269168  0.4959217  0.47145188]
#  [0.77977162 0.78466558 0.77324633 0.75693312 0.72756933]
#  [0.88417618 0.88743883 0.88743883 0.87438825 0.84665579]
#  [0.96737357 0.96900489 0.97553018 0.96900489 0.95595432]]
# power
# Epoch 38: 100%|██████████| 305/305 [00:03<00:00, 86.53batch/s, loss=1.41, acc=0.471]
# val_loss=1.2919
# accuracy
# [[0.53507341 0.54159869 0.5269168  0.50244698 0.47471452]
#  [0.7862969  0.78955954 0.76998369 0.75203915 0.73409462]
#  [0.88743883 0.89559543 0.89233279 0.87275693 0.84502447]
#  [0.96737357 0.97063622 0.97553018 0.97226754 0.95758564]]
# power
# Epoch 39: 100%|██████████| 305/305 [00:03<00:00, 89.79batch/s, loss=1.41, acc=0.472]
# val_loss=1.2939
# accuracy
# [[0.53344209 0.53833605 0.53017945 0.49755302 0.46982055]
#  [0.77977162 0.78466558 0.77161501 0.74877651 0.72920065]
#  [0.88417618 0.89396411 0.88743883 0.87275693 0.84502447]
#  [0.96737357 0.97063622 0.97553018 0.97063622 0.95758564]]
# power
# Epoch 40: 100%|██████████| 305/305 [00:03<00:00, 100.02batch/s, loss=1.41, acc=0.471]
# val_loss=1.2938
# accuracy
# [[0.53833605 0.53833605 0.53181077 0.50244698 0.46818923]
#  [0.77814029 0.78140294 0.77161501 0.75040783 0.72593801]
#  [0.8858075  0.89070147 0.8858075  0.87275693 0.84991843]
#  [0.96737357 0.96900489 0.97553018 0.97063622 0.95595432]]
# power
# Epoch 41: 100%|██████████| 305/305 [00:03<00:00, 84.01batch/s, loss=1.4, acc=0.473]
# val_loss=1.3068
# accuracy
# [[0.53181077 0.53017945 0.52039152 0.49265905 0.46329527]
#  [0.77161501 0.77324633 0.76182708 0.75530179 0.7177814 ]
#  [0.88254486 0.88254486 0.8858075  0.87112561 0.83686786]
#  [0.96574225 0.96737357 0.97226754 0.96737357 0.95269168]]
# power
# Epoch 42: 100%|██████████| 305/305 [00:03<00:00, 83.30batch/s, loss=1.4, acc=0.471]
# val_loss=1.3100
# accuracy
# [[0.53017945 0.52854812 0.51549755 0.49429038 0.46003263]
#  [0.76672104 0.77650897 0.76508972 0.75856444 0.72104405]
#  [0.88254486 0.8858075  0.88417618 0.86786297 0.83523654]
#  [0.96574225 0.96737357 0.97553018 0.96900489 0.95758564]]
# power
# Epoch 43: 100%|██████████| 305/305 [00:03<00:00, 95.54batch/s, loss=1.41, acc=0.469]
# val_loss=1.2899
# accuracy
# [[0.53996737 0.54486134 0.53833605 0.50897227 0.47797716]
#  [0.78466558 0.79282219 0.76835237 0.75367047 0.72920065]
#  [0.88417618 0.89559543 0.88907015 0.8776509  0.84991843]
#  [0.96737357 0.97063622 0.97553018 0.97063622 0.95758564]]
# power
# Epoch 44: 100%|██████████| 305/305 [00:03<00:00, 94.34batch/s, loss=1.41, acc=0.476]
# val_loss=1.2897
# accuracy
# [[0.53507341 0.53833605 0.53507341 0.50734095 0.47797716]
#  [0.78955954 0.78955954 0.76998369 0.76019576 0.73083197]
#  [0.88743883 0.89559543 0.88743883 0.87275693 0.84828711]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 45: 100%|██████████| 305/305 [00:03<00:00, 81.47batch/s, loss=1.41, acc=0.471]
# val_loss=1.2904
# accuracy
# [[0.53670473 0.53996737 0.53181077 0.50734095 0.47797716]
#  [0.77977162 0.78466558 0.76835237 0.76019576 0.73083197]
#  [0.88743883 0.89559543 0.88743883 0.87275693 0.84991843]
#  [0.96737357 0.96900489 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 46: 100%|██████████| 305/305 [00:03<00:00, 85.21batch/s, loss=1.4, acc=0.473]
# val_loss=1.2905
# accuracy
# [[0.53833605 0.54159869 0.53181077 0.50734095 0.47634584]
#  [0.78303426 0.7862969  0.76835237 0.75530179 0.73083197]
#  [0.88907015 0.89559543 0.89070147 0.87601958 0.85154976]
#  [0.96737357 0.97063622 0.97553018 0.96900489 0.95758564]]
# power
# Epoch 47: 100%|██████████| 305/305 [00:03<00:00, 87.79batch/s, loss=1.41, acc=0.466]
# val_loss=1.2987
# accuracy
# [[0.54159869 0.53670473 0.5269168  0.49755302 0.46329527]
#  [0.77977162 0.77977162 0.76835237 0.75693312 0.72430669]
#  [0.88417618 0.88417618 0.88743883 0.87275693 0.84828711]
#  [0.96574225 0.96900489 0.97389886 0.97063622 0.95921697]]
# power
# Epoch 48: 100%|██████████| 305/305 [00:03<00:00, 90.54batch/s, loss=1.41, acc=0.47]
# val_loss=1.2965
# accuracy
# [[0.53996737 0.53670473 0.53017945 0.49918434 0.46818923]
#  [0.77814029 0.78140294 0.77161501 0.75693312 0.72104405]
#  [0.88417618 0.88743883 0.8858075  0.87438825 0.84828711]
#  [0.96737357 0.96900489 0.97389886 0.96900489 0.95921697]]
# power
# Epoch 49: 100%|██████████| 305/305 [00:03<00:00, 82.49batch/s, loss=1.41, acc=0.466]
# val_loss=1.2949
# accuracy
# [[0.53996737 0.53996737 0.5269168  0.5040783  0.46818923]
#  [0.77977162 0.78303426 0.76998369 0.75856444 0.72430669]
#  [0.8858075  0.89070147 0.8858075  0.87275693 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 50: 100%|██████████| 305/305 [00:03<00:00, 80.28batch/s, loss=1.4, acc=0.474]
# val_loss=1.2941
# accuracy
# [[0.53833605 0.53996737 0.52854812 0.5040783  0.46982055]
#  [0.77977162 0.7862969  0.76998369 0.75693312 0.72430669]
#  [0.8858075  0.89233279 0.8858075  0.87275693 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 51: 100%|██████████| 305/305 [00:03<00:00, 89.08batch/s, loss=1.41, acc=0.464]
# val_loss=1.2930
# accuracy
# [[0.53833605 0.53996737 0.53017945 0.50244698 0.47145188]
#  [0.78303426 0.78466558 0.77161501 0.75693312 0.72430669]
#  [0.88417618 0.89233279 0.8858075  0.87112561 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 52: 100%|██████████| 305/305 [00:03<00:00, 88.42batch/s, loss=1.39, acc=0.475]
# val_loss=1.2959
# accuracy
# [[0.53996737 0.53833605 0.5269168  0.50081566 0.46492659]
#  [0.77814029 0.78140294 0.76998369 0.75856444 0.72267537]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.85154976]
#  [0.96737357 0.96900489 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 53: 100%|██████████| 305/305 [00:03<00:00, 80.77batch/s, loss=1.41, acc=0.474]
# val_loss=1.2972
# accuracy
# [[0.53833605 0.53670473 0.53017945 0.49755302 0.46492659]
#  [0.77650897 0.78466558 0.77324633 0.75693312 0.72267537]
#  [0.88417618 0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.96900489 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 54: 100%|██████████| 305/305 [00:03<00:00, 85.54batch/s, loss=1.4, acc=0.474]
# val_loss=1.2967
# accuracy
# [[0.53996737 0.53670473 0.53017945 0.49755302 0.46492659]
#  [0.77650897 0.78140294 0.77161501 0.75693312 0.72104405]
#  [0.88417618 0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.96900489 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 55: 100%|██████████| 305/305 [00:03<00:00, 90.27batch/s, loss=1.41, acc=0.469]
# val_loss=1.2967
# accuracy
# [[0.53833605 0.53670473 0.53181077 0.4959217  0.46492659]
#  [0.77487765 0.78140294 0.77161501 0.75693312 0.72104405]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.96900489 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 56: 100%|██████████| 305/305 [00:03<00:00, 85.62batch/s, loss=1.41, acc=0.472]
# val_loss=1.2960
# accuracy
# [[0.53833605 0.53670473 0.53181077 0.49918434 0.46492659]
#  [0.77814029 0.78466558 0.76998369 0.75530179 0.72267537]
#  [0.88417618 0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.96900489 0.97389886 0.96900489 0.95595432]]
# power
# Epoch 57: 100%|██████████| 305/305 [00:03<00:00, 77.47batch/s, loss=1.42, acc=0.47]
# val_loss=1.2952
# accuracy
# [[0.53670473 0.53833605 0.52854812 0.49918434 0.46655791]
#  [0.77814029 0.78303426 0.77161501 0.75693312 0.72267537]
#  [0.88417618 0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.96900489 0.97389886 0.96900489 0.95595432]]
# power
# Epoch 58: 100%|██████████| 305/305 [00:03<00:00, 91.42batch/s, loss=1.39, acc=0.478]
# val_loss=1.2934
# accuracy
# [[0.53670473 0.53833605 0.52854812 0.50081566 0.46982055]
#  [0.78303426 0.7862969  0.77324633 0.75693312 0.72267537]
#  [0.8858075  0.89070147 0.8858075  0.87275693 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 59: 100%|██████████| 305/305 [00:03<00:00, 87.16batch/s, loss=1.4, acc=0.476]
# val_loss=1.2928
# accuracy
# [[0.53670473 0.53833605 0.53017945 0.50244698 0.4730832 ]
#  [0.7862969  0.78466558 0.77161501 0.75530179 0.72593801]
#  [0.8858075  0.89233279 0.8858075  0.86949429 0.84828711]
#  [0.96737357 0.97063622 0.97389886 0.97226754 0.95758564]]
# power
# Epoch 60: 100%|██████████| 305/305 [00:03<00:00, 83.30batch/s, loss=1.4, acc=0.476]
# val_loss=1.2929
# accuracy
# [[0.53670473 0.53833605 0.53017945 0.50244698 0.47145188]
#  [0.78466558 0.7862969  0.77161501 0.75530179 0.72430669]
#  [0.8858075  0.89233279 0.8858075  0.87112561 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 61: 100%|██████████| 305/305 [00:03<00:00, 88.33batch/s, loss=1.4, acc=0.47]
# val_loss=1.2918
# accuracy
# [[0.53833605 0.54159869 0.53344209 0.5040783  0.4730832 ]
#  [0.78792822 0.7862969  0.77161501 0.75530179 0.72593801]
#  [0.8858075  0.89396411 0.8858075  0.87438825 0.84665579]
#  [0.96737357 0.97063622 0.97553018 0.97226754 0.95758564]]
# power
# Epoch 62: 100%|██████████| 305/305 [00:03<00:00, 79.33batch/s, loss=1.4, acc=0.475]
# val_loss=1.2920
# accuracy
# [[0.53833605 0.54159869 0.53344209 0.50244698 0.47145188]
#  [0.7862969  0.7862969  0.77161501 0.75693312 0.72593801]
#  [0.8858075  0.89396411 0.8858075  0.87275693 0.84828711]
#  [0.96737357 0.97063622 0.97553018 0.97226754 0.95758564]]
# power
# Epoch 63: 100%|██████████| 305/305 [00:03<00:00, 85.99batch/s, loss=1.4, acc=0.474]
# val_loss=1.2925
# accuracy
# [[0.53833605 0.53996737 0.53017945 0.50244698 0.4730832 ]
#  [0.78466558 0.78792822 0.77161501 0.75856444 0.72430669]
#  [0.8858075  0.89233279 0.8858075  0.87275693 0.85154976]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 64: 100%|██████████| 305/305 [00:03<00:00, 79.72batch/s, loss=1.41, acc=0.469]
# val_loss=1.2922
# accuracy
# [[0.53670473 0.53996737 0.53017945 0.50244698 0.47145188]
#  [0.78140294 0.7862969  0.77161501 0.75693312 0.72430669]
#  [0.88417618 0.89396411 0.8858075  0.87275693 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 65: 100%|██████████| 305/305 [00:04<00:00, 72.86batch/s, loss=1.41, acc=0.471]
# val_loss=1.2933
# accuracy
# [[0.53670473 0.53996737 0.53017945 0.50081566 0.47145188]
#  [0.78140294 0.7862969  0.77161501 0.75856444 0.72430669]
#  [0.8858075  0.89233279 0.8858075  0.87275693 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 66: 100%|██████████| 305/305 [00:03<00:00, 79.32batch/s, loss=1.4, acc=0.473]
# val_loss=1.2925
# accuracy
# [[0.53670473 0.53996737 0.53017945 0.5040783  0.47145188]
#  [0.78466558 0.78792822 0.77161501 0.75530179 0.72756933]
#  [0.8858075  0.89233279 0.8858075  0.87112561 0.84828711]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 67: 100%|██████████| 305/305 [00:03<00:00, 78.01batch/s, loss=1.4, acc=0.473]
# val_loss=1.2918
# accuracy
# [[0.53670473 0.54159869 0.53017945 0.50244698 0.47145188]
#  [0.7862969  0.7862969  0.77161501 0.75530179 0.72756933]
#  [0.8858075  0.89396411 0.88743883 0.87275693 0.84828711]
#  [0.96737357 0.97063622 0.97553018 0.97226754 0.95758564]]
# power
# Epoch 68: 100%|██████████| 305/305 [00:03<00:00, 78.63batch/s, loss=1.41, acc=0.473]
# val_loss=1.2933
# accuracy
# [[0.53996737 0.53833605 0.52854812 0.5040783  0.47145188]
#  [0.78466558 0.7862969  0.77161501 0.75693312 0.72430669]
#  [0.8858075  0.89233279 0.8858075  0.87275693 0.85154976]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 69: 100%|██████████| 305/305 [00:03<00:00, 78.20batch/s, loss=1.4, acc=0.473]
# val_loss=1.2949
# accuracy
# [[0.53996737 0.53996737 0.5269168  0.50244698 0.46818923]
#  [0.77977162 0.78792822 0.77324633 0.75856444 0.72267537]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95595432]]
# power
# Epoch 70: 100%|██████████| 305/305 [00:04<00:00, 74.04batch/s, loss=1.4, acc=0.476]
# val_loss=1.2949
# accuracy
# [[0.53996737 0.53833605 0.53017945 0.50081566 0.46818923]
#  [0.77977162 0.78792822 0.77324633 0.75856444 0.72267537]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95595432]]
# power
# Epoch 71: 100%|██████████| 305/305 [00:04<00:00, 73.98batch/s, loss=1.4, acc=0.473]
# val_loss=1.2949
# accuracy
# [[0.53996737 0.53670473 0.53017945 0.50081566 0.46818923]
#  [0.77977162 0.78792822 0.77324633 0.75693312 0.72267537]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 72: 100%|██████████| 305/305 [00:04<00:00, 73.03batch/s, loss=1.41, acc=0.468]
# val_loss=1.2945
# accuracy
# [[0.53833605 0.53833605 0.53181077 0.50244698 0.46818923]
#  [0.78466558 0.78792822 0.77324633 0.75693312 0.72430669]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95595432]]
# power
# Epoch 73: 100%|██████████| 305/305 [00:04<00:00, 74.39batch/s, loss=1.41, acc=0.472]
# val_loss=1.2937
# accuracy
# [[0.53996737 0.53833605 0.53017945 0.5040783  0.46982055]
#  [0.78466558 0.7862969  0.77324633 0.75693312 0.72267537]
#  [0.8858075  0.89070147 0.8858075  0.87438825 0.85154976]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 74: 100%|██████████| 305/305 [00:04<00:00, 75.55batch/s, loss=1.4, acc=0.473]
# val_loss=1.2932
# accuracy
# [[0.53996737 0.53833605 0.53017945 0.50244698 0.46818923]
#  [0.78303426 0.7862969  0.77324633 0.75530179 0.72267537]
#  [0.8858075  0.89070147 0.8858075  0.87438825 0.84828711]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 75: 100%|██████████| 305/305 [00:04<00:00, 73.95batch/s, loss=1.41, acc=0.468]
# val_loss=1.2928
# accuracy
# [[0.53833605 0.53833605 0.52854812 0.50244698 0.47145188]
#  [0.78466558 0.78466558 0.77324633 0.75693312 0.72430669]
#  [0.8858075  0.89070147 0.8858075  0.87275693 0.84828711]
#  [0.96737357 0.97063622 0.97389886 0.97226754 0.95758564]]
# power
# Epoch 76: 100%|██████████| 305/305 [00:03<00:00, 78.57batch/s, loss=1.41, acc=0.473]
# val_loss=1.2939
# accuracy
# [[0.53996737 0.53833605 0.53017945 0.5040783  0.46818923]
#  [0.78466558 0.7862969  0.77324633 0.75530179 0.72430669]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 77: 100%|██████████| 305/305 [00:04<00:00, 75.10batch/s, loss=1.4, acc=0.471]
# val_loss=1.2929
# accuracy
# [[0.53670473 0.53833605 0.53181077 0.50244698 0.46982055]
#  [0.78466558 0.7862969  0.77324633 0.75530179 0.72267537]
#  [0.8858075  0.89070147 0.8858075  0.87275693 0.84828711]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 78: 100%|██████████| 305/305 [00:04<00:00, 75.98batch/s, loss=1.41, acc=0.473]
# val_loss=1.2938
# accuracy
# [[0.53670473 0.53670473 0.52854812 0.49918434 0.46982055]
#  [0.77977162 0.78466558 0.76998369 0.75530179 0.72267537]
#  [0.8858075  0.88907015 0.8858075  0.87438825 0.84828711]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95921697]]
# power
# Epoch 79: 100%|██████████| 305/305 [00:03<00:00, 80.20batch/s, loss=1.4, acc=0.477]
# val_loss=1.2928
# accuracy
# [[0.53670473 0.53833605 0.52854812 0.49918434 0.46982055]
#  [0.78303426 0.7862969  0.76998369 0.75530179 0.72430669]
#  [0.88743883 0.89233279 0.8858075  0.87438825 0.84828711]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95921697]]
# power
# Epoch 80: 100%|██████████| 305/305 [00:03<00:00, 94.59batch/s, loss=1.41, acc=0.464]
# val_loss=1.2929
# accuracy
# [[0.53670473 0.53996737 0.52854812 0.49918434 0.47145188]
#  [0.78303426 0.7862969  0.77161501 0.75856444 0.72267537]
#  [0.88743883 0.89070147 0.8858075  0.87438825 0.84828711]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 81: 100%|██████████| 305/305 [00:03<00:00, 89.83batch/s, loss=1.4, acc=0.473]
# val_loss=1.2927
# accuracy
# [[0.53670473 0.53996737 0.52854812 0.50081566 0.4730832 ]
#  [0.78140294 0.7862969  0.77161501 0.75693312 0.72267537]
#  [0.8858075  0.89070147 0.8858075  0.87601958 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 82: 100%|██████████| 305/305 [00:03<00:00, 81.51batch/s, loss=1.41, acc=0.472]
# val_loss=1.2937
# accuracy
# [[0.53670473 0.53670473 0.52854812 0.49918434 0.46818923]
#  [0.77977162 0.7862969  0.76835237 0.75856444 0.72104405]
#  [0.8858075  0.89070147 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95921697]]
# power
# Epoch 83: 100%|██████████| 305/305 [00:03<00:00, 87.30batch/s, loss=1.4, acc=0.473]
# val_loss=1.2941
# accuracy
# [[0.53670473 0.53670473 0.53017945 0.49918434 0.46818923]
#  [0.77977162 0.78466558 0.76998369 0.75693312 0.72104405]
#  [0.8858075  0.88907015 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95921697]]
# power
# Epoch 84: 100%|██████████| 305/305 [00:03<00:00, 87.23batch/s, loss=1.41, acc=0.47]
# val_loss=1.2924
# accuracy
# [[0.53670473 0.53996737 0.53017945 0.5040783  0.47145188]
#  [0.78466558 0.78792822 0.77161501 0.75530179 0.72593801]
#  [0.8858075  0.89233279 0.8858075  0.87275693 0.85154976]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 85: 100%|██████████| 305/305 [00:03<00:00, 84.85batch/s, loss=1.41, acc=0.469]
# val_loss=1.2949
# accuracy
# [[0.53996737 0.53670473 0.52854812 0.50081566 0.46655791]
#  [0.77977162 0.78303426 0.76998369 0.75530179 0.72267537]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 86: 100%|██████████| 305/305 [00:03<00:00, 83.75batch/s, loss=1.4, acc=0.473]
# val_loss=1.2946
# accuracy
# [[0.53996737 0.53670473 0.52854812 0.50081566 0.46818923]
#  [0.78140294 0.78792822 0.77324633 0.75856444 0.72104405]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 87: 100%|██████████| 305/305 [00:03<00:00, 89.63batch/s, loss=1.41, acc=0.472]
# val_loss=1.2951
# accuracy
# [[0.53833605 0.53833605 0.5269168  0.49918434 0.46982055]
#  [0.77977162 0.78792822 0.77324633 0.75856444 0.72104405]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 88: 100%|██████████| 305/305 [00:04<00:00, 76.21batch/s, loss=1.41, acc=0.47]
# val_loss=1.2950
# accuracy
# [[0.53833605 0.53670473 0.53017945 0.49755302 0.46655791]
#  [0.78140294 0.78792822 0.77161501 0.75856444 0.72104405]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 89: 100%|██████████| 305/305 [00:03<00:00, 85.45batch/s, loss=1.4, acc=0.47]
# val_loss=1.2948
# accuracy
# [[0.53996737 0.53670473 0.53181077 0.49918434 0.46818923]
#  [0.78140294 0.78792822 0.77161501 0.75856444 0.72104405]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 90: 100%|██████████| 305/305 [00:03<00:00, 88.96batch/s, loss=1.41, acc=0.469]
# val_loss=1.2938
# accuracy
# [[0.53996737 0.53833605 0.53017945 0.50244698 0.46982055]
#  [0.78303426 0.7862969  0.77324633 0.75693312 0.72267537]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.85154976]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 91: 100%|██████████| 305/305 [00:03<00:00, 84.34batch/s, loss=1.42, acc=0.468]
# val_loss=1.2941
# accuracy
# [[0.53996737 0.53833605 0.53017945 0.50244698 0.47145188]
#  [0.78140294 0.78792822 0.77161501 0.75693312 0.72104405]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95595432]]
# power
# Epoch 92: 100%|██████████| 305/305 [00:03<00:00, 84.98batch/s, loss=1.41, acc=0.468]
# val_loss=1.2940
# accuracy
# [[0.53996737 0.53833605 0.53344209 0.50244698 0.46818923]
#  [0.78303426 0.78792822 0.77324633 0.75693312 0.72267537]
#  [0.8858075  0.88743883 0.8858075  0.87438825 0.84991843]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95595432]]
# power
# Epoch 93: 100%|██████████| 305/305 [00:03<00:00, 84.06batch/s, loss=1.4, acc=0.471]
# val_loss=1.2951
# accuracy
# [[0.53996737 0.53670473 0.52854812 0.49918434 0.46982055]
#  [0.78140294 0.78792822 0.76998369 0.75856444 0.72104405]
#  [0.8858075  0.88907015 0.8858075  0.87438825 0.84828711]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95758564]]
# power
# Epoch 94: 100%|██████████| 305/305 [00:03<00:00, 90.35batch/s, loss=1.4, acc=0.473]
# val_loss=1.2935
# accuracy
# [[0.53833605 0.53833605 0.53344209 0.50081566 0.46818923]
#  [0.78466558 0.78792822 0.77324633 0.75693312 0.72430669]
#  [0.8858075  0.88743883 0.8858075  0.87601958 0.84665579]
#  [0.96737357 0.97063622 0.97389886 0.96900489 0.95595432]]
# power
# Epoch 95: 100%|██████████| 305/305 [00:03<00:00, 93.08batch/s, loss=1.41, acc=0.472]
# val_loss=1.2922
# accuracy
# [[0.53670473 0.53833605 0.53017945 0.50081566 0.47145188]
#  [0.7862969  0.7862969  0.77324633 0.75693312 0.72430669]
#  [0.8858075  0.89396411 0.8858075  0.87438825 0.84828711]
#  [0.96737357 0.97063622 0.97389886 0.97063622 0.95758564]]
# power
# Epoch 96: 100%|██████████| 305/305 [00:03<00:00, 86.50batch/s, loss=1.41, acc=0.472]
# val_loss=1.2925
# accuracy
# [[0.53670473 0.53833605 0.53017945 0.50244698 0.46982055]
#  [0.7862969  0.7862969  0.77324633 0.75530179 0.72430669]
#  [0.8858075  0.89070147 0.8858075  0.87112561 0.84828711]
#  [0.96737357 0.97063622 0.97553018 0.97063622 0.95595432]]
# power
# Epoch 97: 100%|██████████| 305/305 [00:03<00:00, 93.26batch/s, loss=1.41, acc=0.47]
# val_loss=1.2921
# accuracy
# [[0.53670473 0.53833605 0.53181077 0.50081566 0.46982055]
#  [0.7862969  0.78466558 0.77324633 0.75530179 0.72430669]
#  [0.8858075  0.89396411 0.8858075  0.87438825 0.84828711]
#  [0.96737357 0.97063622 0.97553018 0.97063622 0.95758564]]
# power
# Epoch 98: 100%|██████████| 305/305 [00:03<00:00, 87.19batch/s, loss=1.4, acc=0.474]
# val_loss=1.2926
# accuracy
# [[0.53670473 0.53996737 0.53017945 0.5040783  0.46982055]
#  [0.78303426 0.78466558 0.77161501 0.75693312 0.72430669]
#  [0.8858075  0.89070147 0.8858075  0.87275693 0.84665579]
#  [0.96737357 0.97063622 0.97389886 0.97226754 0.95758564]]
# power
# Epoch 99: 100%|██████████| 305/305 [00:03<00:00, 82.21batch/s, loss=1.4, acc=0.47]
# val_loss=1.2928
# accuracy
# [[0.53833605 0.53833605 0.53181077 0.50081566 0.46982055]
#  [0.78466558 0.78466558 0.77324633 0.75530179 0.72430669]
#  [0.8858075  0.89070147 0.8858075  0.87438825 0.84665579]
#  [0.96737357 0.97063622 0.97553018 0.97063622 0.95758564]]
# power
# Finished Training
# {'top1': array([0.53833605, 0.53833605, 0.53181077, 0.50081566, 0.46982055]), 'top2': array([0.78466558, 0.78466558, 0.77324633, 0.75530179, 0.72430669]), 'top3': array([0.8858075 , 0.89070147, 0.8858075 , 0.87438825, 0.84665579]), 'top5': array([0.96737357, 0.97063622, 0.97553018, 0.97063622, 0.95758564])}
# Results saved at: ./plot/test_acc.mat
